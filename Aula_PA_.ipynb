# %% [markdown]
# <a href="https://colab.research.google.com/github/Vil-Yo/Aula-PA-2/blob/main/Aula_PA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aula de Programação e Algoritimo**
#
#
# * Calcular a área de uma sala
#   * Medir o comprimento da sala
#   * Medir a Largura da sala
# * Entrada
# * Processamento
#   * Fazer a multiplicação do comprimento pela largura
# * saída
#   * Mostrar o resultado

# %%
# entrada

comprimento = 7 #metros
largura = 5 #metros

# %%
#processamento

area = comprimento * largura

# %%
print (f"área total foi: {area} metros quadrados")
# Out:
# área total foi: 35 metros quadrados

# %%
#entrada

lado = 3

#processamento

resultado = lado * lado

#saida

print (f"O tamanho do quadrado = {resultado} metros ")
# Out:
# O tamanho do quadrado = 9 metros

# %% [markdown]
# Atividade:
#
# * Escrever um algoritimo e depois o programa que recebe um número e calcula o dobro desse número

# %% [markdown]
# #entrada
# * encontrar o valor do número
# #processamento
# * fazer o calculo do número vezes dois
# #saída
# * exibir o resultado do calculo

# %%
#entrada
import random
numero = random.randint(1, 40)

#processamento

dobro = numero * 2

#saída

print (f"o dobro de {numero} é {dobro}")
# Out:
# o dobro de 3 é 6

# %% [markdown]
# #Operadores aritiméticos
#
# * soma = +
# * subtracao = -
# * multiplicacao *
# * divisao = /

# %% [markdown]
# #Escrever um algoritimo e o programa que receba quatro notas do aluno e calcula a média dessas notas e mostre a média

# %% [markdown]
# #entrada
# * notas do aluno
# #processamento
# * somar nota 1 + nota 2 + nota 3 + nota 4
# * resultado = nota 5
# * dividir nota 5 por 4
# * resultado 2 = nota 5 dividido por 4
# #saida
# * exibir a mensagem: seu resultado foi resultado 2
